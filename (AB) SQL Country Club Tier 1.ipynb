# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT *
        FROM FACILITIES
        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# (0, 'Tennis Court 1', 5, 25, 10000, 200)
# (1, 'Tennis Court 2', 5, 25, 8000, 200)
# (2, 'Badminton Court', 0, 15.5, 4000, 50)
# (3, 'Table Tennis', 0, 5, 320, 10)
# (4, 'Massage Room 1', 9.9, 80, 4000, 3000)
# (5, 'Massage Room 2', 9.9, 80, 4000, 3000)
# (6, 'Squash Court', 3.5, 17.5, 5000, 80)
# (7, 'Snooker Table', 0, 5, 450, 15)
# (8, 'Pool Table', 0, 5, 400, 15)

# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query10 = """
SELECT subquery.facid, subquery.name, ROUND(SUM(subquery.memorguesttotal),2) AS revenue 
FROM (SELECT b.facid, f.name,
      CASE WHEN b.memid  > 0
               THEN membercost*slots
               ELSE guestcost*slots
      END AS memorguesttotal
FROM Bookings AS b
INNER JOIN Facilities AS f
ON b.facid = f.facid) AS subquery
GROUP by subquery.facid
HAVING revenue < 1000
ORDER by revenue DESC;


        """
    cur.execute(query10)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# (8, 'Pool Table', 270.0)
# (7, 'Snooker Table', 240.0)
# (3, 'Table Tennis', 180.0)

# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query11 = """
        SELECT m1.surname || ', ' || m1.firstname AS fullname, m2.surname || ', ' || m2.firstname AS reccfullname
        FROM Members as m1
        INNER JOIN Members as m2
        ON m1.recommendedby = m2.memid
        ORDER by fullname
 
        """
    cur.execute(query11)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# ('Bader, Florence', 'Stibbons, Ponder')
# ('Baker, Anne', 'Stibbons, Ponder')
# ('Baker, Timothy', 'Farrell, Jemima')
# ('Boothe, Tim', 'Rownam, Tim')
# ('Butters, Gerald', 'Smith, Darren')
# ('Coplin, Joan', 'Baker, Timothy')
# ('Crumpet, Erica', 'Smith, Tracy')
# ('Dare, Nancy', 'Joplette, Janice')
# ('Genting, Matthew', 'Butters, Gerald')
# ('Hunt, John', 'Purview, Millicent')
# ('Jones, David', 'Joplette, Janice')
# ('Jones, Douglas', 'Jones, David')
# ('Joplette, Janice', 'Smith, Darren')
# ('Mackenzie, Anna', 'Smith, Darren')
# ('Owen, Charles', 'Smith, Darren')
# ('Pinker, David', 'Farrell, Jemima')
# ('Purview, Millicent', 'Smith, Tracy')
# ('Rumney, Henrietta', 'Genting, Matthew')
# ('Sarwin, Ramnaresh', 'Bader, Florence')
# ('Smith, Jack', 'Smith, Darren')
# ('Stibbons, Ponder', 'Tracy, Burton')
# ('Worthington-Smyth, Henry', 'Smith, Tracy')

# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query12 = """
        SELECT m.firstname, m.surname, f.name, COUNT(b.facid)
        FROM Bookings AS b
        INNER JOIN Facilities AS f
        ON b.facid = f.facid
        INNER JOIN members as m
        ON m.memid = b.memid
        GROUP by m.firstname, m.surname, f.name
        HAVING m.memid > 0
        ORDER by COUNT(b.facid) DESC
        
        """
    cur.execute(query12)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# ('Tim', 'Rownam', 'Pool Table', 241)
# ('Darren', 'Smith', 'Badminton Court', 132)
# ('Timothy', 'Baker', 'Pool Table', 85)
# ('Tim', 'Rownam', 'Massage Room 1', 80)
# ('Anna', 'Mackenzie', 'Pool Table', 70)
# ('Tim', 'Rownam', 'Table Tennis', 69)
# ('Janice', 'Joplette', 'Snooker Table', 68)
# ('Tracy', 'Smith', 'Pool Table', 61)
# ('Gerald', 'Butters', 'Tennis Court 1', 57)
# ('Tim', 'Boothe', 'Tennis Court 2', 52)
# ('Anne', 'Baker', 'Squash Court', 49)
# ('Tracy', 'Smith', 'Snooker Table', 45)
# ('Tim', 'Boothe', 'Snooker Table', 43)
# ('Florence', 'Bader', 'Table Tennis', 42)
# ('Charles', 'Owen', 'Tennis Court 2', 41)
# ('Tim', 'Boothe', 'Massage Room 1', 36)
# ('Anne', 'Baker', 'Tennis Court 2', 35)
# ('Burton', 'Tracy', 'Squash Court', 35)
# ('Gerald', 'Butters', 'Snooker Table', 34)
# ('Florence', 'Bader', 'Snooker Table', 33)
# ('Henry', 'Worthington-Smyth', 'Pool Table', 33)
# ('Gerald', 'Butters', 'Massage Room 1', 32)
# ...

# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query13 = """
       SELECT f.name, strftime('%m', b.starttime) AS month, COUNT(b.slots) AS count
        FROM Bookings AS b
        INNER JOIN Facilities AS f
        ON b.facid = f.facid
        WHERE b.memid > 0
        GROUP by f.name, month
        ORDER by month 
        """
    cur.execute(query13)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# ('Badminton Court', '07', 51)
# ('Massage Room 1', '07', 77)
# ('Massage Room 2', '07', 4)
# ('Pool Table', '07', 103)
# ('Snooker Table', '07', 68)
# ('Squash Court', '07', 23)
# ('Table Tennis', '07', 48)
# ('Tennis Court 1', '07', 65)
# ('Tennis Court 2', '07', 41)
# ('Badminton Court', '08', 132)
# ('Massage Room 1', '08', 153)
# ('Massage Room 2', '08', 9)
# ('Pool Table', '08', 272)
# ('Snooker Table', '08', 154)
# ('Squash Court', '08', 85)
# ('Table Tennis', '08', 143)
# ('Tennis Court 1', '08', 111)
# ('Tennis Court 2', '08', 109)
# ('Badminton Court', '09', 161)
# ('Massage Room 1', '09', 191)
# ('Massage Room 2', '09', 14)
# ('Pool Table', '09', 408)
# ('Snooker Table', '09', 199)
# ('Squash Court', '09', 87)
# ('Table Tennis', '09', 194)
# ('Tennis Court 1', '09', 132)
# ('Tennis Court 2', '09', 126)
